# %% [markdown]
# # 시각화 도구

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
import matplotlib as plt

plt.__version__
# Out:
# '3.7.1'

# %%
# !pip3 install matplotlib

# %%
df = pd.read_excel("D:/sample_data/시도별 전출입 인구수.xlsx")
df.head()
# Out:
#    전출지별   전입지별      1970      1971      1972      1973      1974      1975  \
# 0  전출지별   전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1    전국     전국   4046536   4210164   3687938   4860418   5297969   9011440
# 2   NaN  서울특별시   1742813   1671705   1349333   1831858   2050392   3396662
# 3   NaN  부산광역시    448577    389797    362202    482061    680984    805979
# 4   NaN  대구광역시         -         -         -         -         -         -
#
#        1976      1977  ...      2008      2009      2010      2011      2012  \
# 0  이동자수 (명)  이동자수 (명)  ...  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1   6773250   7397623  ...   8808256   8487275   8226594   8127195   7506691
# 2   2756510   2893403  ...   2025358   1873188   1733015   1721748   1555281
# 3    724664    785117  ...    514502    519310    519334    508043    461042
# 4         -         -  ...    409938    398626    370817    370563    348642
#
#        2013      2014      2015      2016      2017
# ...

# %%
import matplotlib.pyplot as plt

# %%
df = df.fillna(method='ffill') # 누락값(NaN)을 채움 앞 데이터로 
df
# Out:
#         전출지별     전입지별      1970      1971      1972      1973      1974  \
# 0       전출지별     전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1         전국       전국   4046536   4210164   3687938   4860418   5297969
# 2         전국    서울특별시   1742813   1671705   1349333   1831858   2050392
# 3         전국    부산광역시    448577    389797    362202    482061    680984
# 4         전국    대구광역시         -         -         -         -         -
# ..       ...      ...       ...       ...       ...       ...       ...
# 320  제주특별자치도     전라북도       139       202       141       210       219
# 321  제주특별자치도     전라남도       631       965       857       952      1133
# 322  제주특별자치도     경상북도       374       619       468       576       625
# 323  제주특별자치도     경상남도       474       479       440       571      1208
# 324  제주특별자치도  제주특별자치도      9290     12427     12210     16158     19580
#
#          1975      1976      1977  ...      2008      2009      2010  \
# ...

# %%
df_seoul = df[(df['전출지별'] == '서울특별시')&
             (df['전입지별'] != '서울특별시')]  # 전출지가 서울특별시이고 전입지가 서울특별시가 아닌
df_seoul
# Out:
#      전출지별     전입지별     1970     1971     1972     1973     1974     1975  \
# 19  서울특별시       전국  1448985  1419016  1210559  1647268  1819660  2937093
# 21  서울특별시    부산광역시    11568    11130    11768    16307    22220    27515
# 22  서울특별시    대구광역시        -        -        -        -        -        -
# 23  서울특별시    인천광역시        -        -        -        -        -        -
# 24  서울특별시    광주광역시        -        -        -        -        -        -
# 25  서울특별시    대전광역시        -        -        -        -        -        -
# 26  서울특별시    울산광역시        -        -        -        -        -        -
# 27  서울특별시  세종특별자치시        -        -        -        -        -        -
# 28  서울특별시      경기도   130149   150313    93333   143234   149045   253705
# 29  서울특별시      강원도     9352    12885    13561    16481    15479    27837
# 30  서울특별시     충청북도     6700     9457    10853    12617    11786    21073
# 31  서울특별시     충청남도    15954    18943    23406    27139    25509    51205
# ...

# %%
del df_seoul['전출지별']
df_seoul
# Out:
#        전입지별     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %%
df_seoul.rename({'전입지별':'전입지'}, axis = 1, inplace=True)
# Out:
# C:\Users\rkdau\AppData\Local\Temp\ipykernel_10168\3835456912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul.rename({'전입지별':'전입지'}, axis = 1, inplace=True)

# %%
df_seoul = df_seoul.set_index('전입지')
df_seoul.head()
# Out:
#           1970     1971     1972     1973     1974     1975     1976     1977  \
# 전입지
# 전국     1448985  1419016  1210559  1647268  1819660  2937093  2495620  2678007
# 부산광역시    11568    11130    11768    16307    22220    27515    23732    27213
# 대구광역시        -        -        -        -        -        -        -        -
# 인천광역시        -        -        -        -        -        -        -        -
# 광주광역시        -        -        -        -        -        -        -        -
#
#           1978     1979  ...     2008     2009     2010     2011     2012  \
# 전입지                      ...
# 전국     3028911  2441242  ...  2083352  1925452  1848038  1834806  1658928
# 부산광역시    29856    28542  ...    17353    17738    17418    18816    16135
# 대구광역시        -        -  ...     9720    10464    10277    10397    10135
# 인천광역시        -        -  ...    50493    45392    46082    51641    49640
# 광주광역시        -        -  ...    10846    11725    11095    10587    10154
#
# ...

# %%
sr_one = df_seoul.loc['경기도']
sr_one
# Out:
# 1970    130149
# 1971    150313
# 1972     93333
# 1973    143234
# 1974    149045
# 1975    253705
# 1976    202276
# 1977    207722
# 1978    237684
# 1979    278411
# 1980    297539
# 1981    252073
# 1982    320174
# 1983    400875
# 1984    352238
# 1985    390265
# 1986    412535
# 1987    405220
# 1988    415174
# 1989    412933
# 1990    473889
# 1991    384714
# 1992    428344
# 1993    502584
# 1994    542204
# 1995    599411
# 1996    520566
# 1997    495454
# 1998    407050
# 1999    471841
# 2000    435573
# 2001    499575
# 2002    516765
# 2003    457656
# 2004    400206
# 2005    414621
# 2006    449632
# 2007    431637
# 2008    412408
# 2009    398282
# 2010    410735
# 2011    373771
# 2012    354135
# 2013    340801
# 2014    332785
# 2015    359337
# 2016    370760
# 2017    342433
# Name: 경기도, dtype: object

# %%
sr_one.index
# Out:
# Index(['1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978',
#        '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987',
#        '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017'],
#       dtype='object')

# %%
plt.plot(sr_one.index, sr_one.values) # plot(x,y)

# %%
plt.title('서울 -> 경기 인구 이동')
# Out:
# Text(0.5, 1.0, '서울 -> 경기 인구 이동')

# %%
plt.xlabel('연도')
plt.ylabel('이동 인구 수')
# Out:
# Text(0.5, 0, '연도')
# C:\Users\rkdau\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\rkdau\anaconda3\Lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\rkdau\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\rkdau\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from matplotlib import font_manager, rc
font_path = "C:/Users/rkdau/AppData/Local/Microsoft/Windows/Fonts/a꽃피는봄.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)
plt.plot(sr_one.index,sr_one.values)

plt.plot(sr_one.index, sr_one.values) # plot(x,y)

plt.title('서울 -> 경기 인구 이동')
plt.xlabel('연도')
plt.ylabel('이동 인구 수')
plt.show()
# Out:
# Text(0, 0.5, '이동 인구 수')

# %%
plt.figure(figsize=(14,5))# 사이즈 키우기
plt.xticks(rotation=45) # x의 값들을 45도 돌려서 표현
plt.plot(sr_one.index,sr_one.values)

plt.plot(sr_one.index, sr_one.values) # plot(x,y)

plt.title('서울 -> 경기 인구 이동')
plt.xlabel('연도')
plt.ylabel('이동 인구 수')
plt.legend(labels=['서울 -> 경기'], loc='best')
plt.show()

# %%
plt.style.use('ggplot')
from matplotlib import font_manager, rc
font_path = "C:/Users/rkdau/AppData/Local/Microsoft/Windows/Fonts/a꽃피는봄.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)
plt.figure(figsize=(14,5))# 사이즈 키우기
plt.xticks(size=10, rotation='vertical') # x의 값들을 45도 돌려서 표현
plt.plot(sr_one.index,sr_one.values,marker='o',markersize=10)

plt.plot(sr_one.index, sr_one.values) # plot(x,y)

plt.title('서울 -> 경기 인구 이동')
plt.xlabel('연도')
plt.ylabel('이동 인구 수')
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)
plt.show()

# %%
plt.style.use('ggplot')

plt.figure(figsize=(14,5))# 사이즈 키우기

plt.xticks(size=10, rotation='vertical') # x의 값들을 45도 돌려서 표현

plt.plot(sr_one.index,sr_one.values,marker='o',markersize=10)

plt.plot(sr_one.index, sr_one.values) # plot(x,y)

plt.title('서울 -> 경기 인구 이동')
plt.xlabel('연도')
plt.ylabel('이동 인구 수')
plt.legend(labels=['서울 -> 경기'], loc='best', fontsize=15)

plt.ylim(50000,800000)

plt.annotate('',
            xy=(20, 620000),
            xytext=(2, 290000),
            xycoords='data',
            arrowprops=dict(arrowstyle='->', color ='skyblue', lw=5),
            ) #화살표 서식

plt.annotate('',
            xy=(47, 450000),
            xytext=(30, 580000),
            xycoords='data',
            arrowprops=dict(arrowstyle='->', color ='olive', lw=5),
            ) #화살표 서식

plt.annotate('인구이동 증가(1970-1955)',
            xy=(9, 380000),
            rotation = 25,
            va = 'baseline',
            ha='center',
            fontsize = 15,
            ) #화살표 서식
    
plt.annotate('인구이동 감소(1995-2017)',
            xy=(40, 500000),
            rotation = -11,
            va = 'baseline',
            ha='center',
            fontsize = 15,
            ) #화살표 서식
plt.show()

# %%
plt.style.use('ggplot')

fig = plt.figure(figsize=(10,10))# 사이즈 키우기
ax1 = fig.add_subplot(2,1,1)# (행의 개수, 열의 개수, n번째 위치)
ax2 = fig.add_subplot(2,1,2)

ax1.plot(sr_one,'o',markersize=10)
ax2.plot(sr_one,marker='o', markerfacecolor='green', markersize= 10,
        color = 'olive', linewidth=2, label='서울 -> 경기')
ax2.legend(loc='best')

ax1.set_ylim(50000,800000)
ax2.set_ylim(50000,800000)

ax1.set_xicklabels(sr_one.index, rotation=75)
ax2.set_xicklabels(sr_one.index, rotation=75)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 15
#      12 ax1.set_ylim(50000,800000)
#      13 ax2.set_ylim(50000,800000)
# ---> 15 ax1.set_xicklabels(sr_one.index, rotation=75)
#      16 ax2.set_xicklabels(sr_one.index, rotation=75)
#
# AttributeError: 'Axes' object has no attribute 'set_xicklabels'

# %%
fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1,1,1)

ax.plot(sr_one,marker='o', markerfacecolor='orange', markersize= 5,
        color = 'olive', linewidth=2, label='서울 -> 경기')
ax.legend(loc='best')

ax.set_ylim(50000,800000)

ax.set_title('서울->경기 인구 이동',size=20)

ax.set_xlabel('기간', size=12)
ax.set_ylabel('이동 인구', size=12)

ax.set_xticklabels(sr_one.index, rotation=75)

ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)

plt.show()
# Out:
# C:\Users\rkdau\AppData\Local\Temp\ipykernel_10168\3714618637.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(sr_one.index, rotation=75)

# %%
col_years_lst = list(range(1970, 2018))
col_years=[]
for i in col_years_lst :
    col_years.append(str(i))
col_years[:10]
# Out:
# ['1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979']

# %%
df_3 = df_seoul.loc[['충청남도','경상북도','강원도'], col_years]
df_3
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
#
#       ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지   ...
# 충청남도  ...  27458  24889  24522  24723  22269  21486  21473  22299  21741
# 경상북도  ...  15425  16569  16042  15818  15191  14420  14456  15113  14236
# 강원도   ...  23668  23331  22736  23624  22332  20601  21173  22659  21590
#
#        2017
# 전입지
# 충청남도  21020
# 경상북도  12464
# 강원도   21016
#
# [3 rows x 48 columns]

# %%
plt.style.use('ggplot')

fig = plt.figure(figsize=(20,5))
ax = fig.add_subplot(1,1,1)

ax.plot(col_years, df_3.loc['충청남도', :], marker = 'o', markerfacecolor='green', markersize=10, color='olive', 
        linewidth=2, label ='서울 -> 충남' )
ax.plot(col_years, df_3.loc['경상북도', :], marker = 'o', markerfacecolor='blue', markersize=10, color='skyblue', 
        linewidth=2, label ='서울 -> 경북' )
ax.plot(col_years, df_3.loc['강원도', :], marke r = 'o', markerfacecolor='red', markersize=10, color='olive', 
        linewidth=2, label ='서울 -> 강원' )

ax.legend(loc='best')

# %%
df_4 = df_seoul.loc[['충청남도','경상북도','강원도','전라남도'], col_years]
df_4 = df_4.transpose()

# %%
col_years = list(map(str, range(1970,2018)))
df_4.plot(kind='area', stacked=False, alpha=0.2, figsize=(20, 10))

plt.title('서울 -> 타도시 인구 이동', size = 30)
plt.ylabel('이동 인구 수', size=20)
plt.xlabel('기간', size=20)
plt.legend(loc='best', fontsize=15)

plt.show()

# %%
col_years = list(map(str, range(1970,2018)))
df_4.index = df_4.index.map(int)
ax = df_4.plot(kind='area', stacked=True, alpha=0.2, figsize=(20, 10))

ax.set_title('서울 -> 타도시 인구 이동', size = 30, color='brown', weight='bold')
ax.set_ylabel('이동 인구 수', size=20, color='blue')
ax.set_xlabel('기간', size=20, color='blue')
ax.legend(loc='best', fontsize=15)

plt.show()
# Out:
# C:\Users\rkdau\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
c_years = list(map(str, range(2010, 2018))) # map을 이용해서 2010부터 2017까지 str 적용
df_5 = df_seoul.loc[['충청남도', '경상북도', '강원도', '전라남도'], c_years]
df_5 = df_5.transpose()

plt.style.use('ggplot')

df_5.index = df_5.index.map(int)

df_5.plot(kind = 'bar', figsize=(20, 10), width=0.7,color=['orange','green', '#33b8bd', 'blue'])

plt.title('서울 -> 타도시 인구 이동', size = 30)
plt.ylabel('이동 인구 수', size = 20)
plt.xlabel('기간', size = 20)
plt.ylim(5000, 30000)
plt.legend(loc = 'best', fontsize=15)

plt.show()

# %%
df_5['합계'] = df_5.sum(axis=1)
df_5
# Out:
# 전입지    충청남도   경상북도    강원도   전라남도       합계
# 2010  24522  16042  22736  16429  79729.0
# 2011  24723  15818  23624  15974  80139.0
# 2012  22269  15191  22332  14765  74557.0
# 2013  21486  14420  20601  14187  70694.0
# 2014  21473  14456  21173  14591  71693.0
# 2015  22299  15113  22659  14598  74669.0
# 2016  21741  14236  21590  13065  70632.0
# 2017  21020  12464  21016  12426  66926.0

# %%
df_total = df_5[['합계']].sort_values(by ='합계', ascending=True)

plt.style.use('ggplot')

df_total.plot(kind='barh', color='cornflowerblue', width=0.5, figsize=(10,5))

plt.title('서울->타시도 인구 이동')
plt.ylabel('년도')
plt.xticks(rotation= 45)
plt.xlabel('이동 인구')
# Out:
# Text(0.5, 0, '이동 인구')

# %%
df = pd.read_excel('D:/sample_data/남북한발전전력량.xlsx', convert_float=True) # 엑셀에 있는 숫자 데이터들을 실수로 변환
df = df.loc[5:9]
df.head()
# Out:
# C:\Users\rkdau\AppData\Local\Temp\ipykernel_10168\2656436585.py:1: FutureWarning: convert_float is deprecated and will be removed in a future version.
#   df = pd.read_excel('D:/sample_data/남북한발전전력량.xlsx', convert_float=True)
#   전력량 (억㎾h) 발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997  ... 2007 2008  \
# 5        북한     합계  277  263  247  221  231  230  213  193  ...  236  255
# 6       NaN     수력  156  150  142  133  138  142  125  107  ...  133  141
# 7       NaN     화력  121  113  105   88   93   88   88   86  ...  103  114
# 8       NaN    원자력    -    -    -    -    -    -    -    -  ...    -    -
#
#   2009 2010 2011 2012 2013 2014 2015 2016
# 5  235  237  211  215  221  216  190  239
# 6  125  134  132  135  139  130  100  128
# 7  110  103   79   80   82   86   90  111
# 8    -    -    -    -    -    -    -    -
#
# [4 rows x 29 columns]

# %%
del df['전력량 (억㎾h)']

# %%
df.head()
# Out:
#   발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997 1998  ... 2007 2008 2009  \
# 5     합계  277  263  247  221  231  230  213  193  170  ...  236  255  235
# 6     수력  156  150  142  133  138  142  125  107  102  ...  133  141  125
# 7     화력  121  113  105   88   93   88   88   86   68  ...  103  114  110
# 8    원자력    -    -    -    -    -    -    -    -    -  ...    -    -    -
#
#   2010 2011 2012 2013 2014 2015 2016
# 5  237  211  215  221  216  190  239
# 6  134  132  135  139  130  100  128
# 7  103   79   80   82   86   90  111
# 8    -    -    -    -    -    -    -
#
# [4 rows x 28 columns]

# %%
df.set_index('발전 전력별', inplace=True)
df = df.T

# %%
df.head()
# Out:
# 발전 전력별   합계   수력   화력 원자력
# 1990    277  156  121   -
# 1991    263  150  113   -
# 1992    247  142  105   -
# 1993    221  133   88   -
# 1994    231  138   93   -

# %%
df.rename(columns={'합계' : '총발전량'},inplace = True)
df['전년도총발전량']= df['총발전량'].shift(1)
df['증감율'] = ((df['총발전량']/ df['전년도총발전량'])-1) * 100

# %%
df.head()
# Out:
# 발전 전력별 총발전량   수력   화력 원자력 전년도총발전량        증감율
# 1990    277  156  121   -    None        NaN
# 1991    263  150  113   -     277  -5.054152
# 1992    247  142  105   -     263   -6.08365
# 1993    221  133   88   -     247 -10.526316
# 1994    231  138   93   -     221   4.524887

# %%
ax1 = df[['수력','화력']].plot(kind='bar', figsize=(20, 10), width = 0.7, stacked=True)

ax2 = ax1.twinx()
ax2.plot(df.index, df['증감율'], ls = '--', marker ='o', markersize=10, color='#00ff1e', label ='전년도대비 증감율(%)')

ax1.set_ylim(0,500)
ax2.set_ylim(-50,50)

ax1.set_xlabel('연도', size=20)
ax1.set_ylabel('발전량(억 Kwh)')
ax2.set_ylabel('전년 대비 증감율(%)')
ax1.legend(loc = 'upper left')
plt.title('북한 전력 발전량 (1990 ~ 2016)', size =30)
ax1.set_xticklabels(df.index,rotation=45)
ax2.set_xticklabels(df.index,rotation=45)
plt.show()
# Out:
# C:\Users\rkdau\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 히스토그램

# %%
df_auto = pd.read_csv("D:/sample_data/auto-mpg.csv", header = None)

df_auto.columns=['mpg','cylinders','displacement','horsepower','weight','acceleration','model year', 'origin','name']

df_auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
plt.style.use('classic')

df_auto['mpg'].plot(kind='hist', bins=10, color='coral', figsize=(10,5))

plt.title('Histogram')
plt.xlabel('mpg')
plt.show()

# %%
df_auto.plot(kind='scatter',x='weight',y='mpg', c= 'coral', s= 10, figsize=(10,5))
plt.title('Scatter Plot - mpg vs. weight')
plt.show()

# %%
cylinders_size = df_auto['cylinders']/ df_auto['cylinders'].max() * 300
cylinders_size
# Out:
# 0      300.0
# 1      300.0
# 2      300.0
# 3      300.0
# 4      300.0
#        ...
# 393    150.0
# 394    150.0
# 395    150.0
# 396    150.0
# 397    150.0
# Name: cylinders, Length: 398, dtype: float64

# %%
cylinders_size = df_auto['cylinders']/ df_auto['cylinders'].max() * 300

df_auto.plot(kind='scatter',x='weight',y='mpg', c= 'coral', s= cylinders_size, figsize=(10,5), alpha = 0.3 )
plt.title('Scatter Plot - mpg vs. weight')
plt.show()

# %%
cylinders_size = df_auto['cylinders']/ df_auto['cylinders'].max() * 300

df_auto.plot(kind='scatter',x='weight',y='mpg', marker='+', c= cylinders_size,cmap='viridis', s=50, figsize=(10,5), alpha = 0.3 )
plt.title('Scatter Plot - mpg vs. weight')

plt.savefig('D:/scatter.png')
plt.savefig('D:/scatter_trans.png', transparent=True)

plt.show()

# %% [markdown]
# # 1-6 파이 차트

# %%
df_auto['count'] = 1
df_origin = df_auto.groupby('origin').sum()
df_origin.head()
# Out:
# C:\Users\rkdau\AppData\Local\Temp\ipykernel_10168\879114308.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_origin = df_auto.groupby('origin').sum()
#            mpg  cylinders  displacement    weight  acceleration  model year  \
# origin
# 1       5000.8       1556       61229.5  837121.0        3743.4       18827
# 2       1952.4        291        7640.0  169631.0        1175.1        5307
# 3       2405.6        324        8114.0  175477.0        1277.6        6118
#
#         count
# origin
# 1         249
# 2          70
# 3          79

# %%
df_origin.index = ['USA', 'EU', 'JAPAN']

# %%
df_origin
# Out:
#           mpg  cylinders  displacement    weight  acceleration  model year  \
# USA    5000.8       1556       61229.5  837121.0        3743.4       18827
# EU     1952.4        291        7640.0  169631.0        1175.1        5307
# JAPAN  2405.6        324        8114.0  175477.0        1277.6        6118
#
#        count
# USA      249
# EU        70
# JAPAN     79

# %%
df_origin['count'].plot(kind='pie',
                       figsize = (7, 5),
                       autopct='%1.1f%%',
                       startangle=10,
                       colors=['chocolate','bisque','cadetblue']
                       )
plt.title('Model Origin', size = 20)
plt.axis('equal')
plt.legend(labels=df_origin.index, loc='upper right')
plt.show()

# %% [markdown]
# # 박스 플롯

# %%
df_auto['origin'] == 1
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 393     True
# 394    False
# 395     True
# 396     True
# 397     True
# Name: origin, Length: 398, dtype: bool

# %%
fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.boxplot(x=[df_auto[df_auto['origin']==1]['mpg'],
              [df_auto[df_auto['origin']==2]['mpg'],
              [df_auto[df_auto['origin']==3]['mpg']],
               labels=['USA','EU','JAPAN'],
               vert=True)
               
ax2.boxplot(x=[df_auto[df_auto['origin']==1]['mpg'],
              [df_auto[df_auto['origin']==2]['mpg'],
              [df_auto[df_auto['origin']==3]['mpg']],
               labels=['USA','EU','JAPAN'],
               vert=True)   
        
ax1.set_title('제조국가별 연비 분포(수직 박스 플롯)')
ax2.set_title('제조국가별 연비 분포(수평 박스 플롯)')
               
plt.show()
# Out:
#   Cell In[93], line 9
#     vert=True)
#              ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '[' on line 6

# %%
import seaborn as sns

titanic = sns.load_dataset('titanic')
print(titanic.head())
print('\n')
print(titanic.info())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
titanic = sns.load_dataset('titanic')

sns.set_style('darkgrid')

fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x='age',
           y='fare',
           data=titanic,
           ax=ax1,
           )

sns.regplot(x='age',
           y='fare',
           data=titanic,
           ax=ax2,
           fit_reg=False)

plt.show()

# %%
fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(1, 3, 1)
ax2 = fig.add_subplot(1, 3, 2)
ax3 = fig.add_subplot(1, 3, 3)

sns.distplot(titanic['fare'], ax=ax1)

sns.kdeplot(x='fare',data=titanic, ax=ax2)

sns.histplot(x='fare',data=titanic, ax=ax3)

ax1.set_title('titanic fare - hist/ked')
ax2.set_title('titanic fare - ked')
ax3.set_title('titanic fare - hist')

plt.show()
# Out:
# C:\Users\rkdau\AppData\Local\Temp\ipykernel_10168\1791734985.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['fare'], ax=ax1)

# %%
table = titanic.pivot_table(index=['sex'], columns=['class'], aggfunc='size')

sns.heatmap(table,
           annot=True, fmt='d',
           cmap='YlGnBu',
           linewidth=.5,
           cbar=False)

plt.show()

# %%
titanic = sns.load_dataset('titanic')

sns.set_style('whitegrid')

fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.stripplot(x='class',
            y='age',
            data=titanic,
            ax=ax1)

sns.swarmplot(x='class',
            y='age',
            data=titanic,
            ax=ax2)

ax1.set_title('Strip Plot')
ax2.set_title('Strip Plot')

plt.show()
# Out:
# C:\Users\rkdau\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\rkdau\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(1,3,1)
ax2 = fig.add_subplot(1,3,2)
ax3 = fig.add_subplot(1,3,3)

sns.barplot(x='sex', y='survived', data=titanic, ax=ax1)

sns.barplot(x='sex', y='survived', data=titanic,hue = 'class', ax=ax2)

sns.barplot(x='sex', y='survived', data=titanic,hue = 'class',dodge=False, ax=ax3)

ax1.set_title('titanic survived - sex')
ax2.set_title('titanic survived - sex/class')
ax3.set_title('titanic survived - sex/class(stacked)')
# Out:
# Text(0.5, 1.0, 'titanic survived - sex/class(stacked)')

# %%
sns.countplot(x='class', palette='Set1', data=titanic, ax=ax1)

sns.countplot(x='class', hue='who', palette='Set2', data= titanic, ax=ax2)

sns.countplot(x='class', hue='who', palette='Set3',dodge=False, data= titanic, ax=ax3)

ax1.set_title('titanic class')
ax2.set_title('titanic class - who')
ax3.set_title('titanic class - who(stacked)')

plt.show()

# %%
titanic = sns.load_dataset('titanic')

sns.set_style('whitegrid')

fig = plt.figure(figsize=(15, 10))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

sns.boxplot(x='alive', y='age', data=titanic, ax= ax1)

sns.boxplot(x='alive', y='age',hue ='sex', data=titanic, ax= ax2)
sns.violinplot(x='alive', y='age', data=titanic, ax= ax3)
sns.violinplot(x='alive', y='age',hue ='sex', data=titanic, ax= ax4)

plt.show()

# %%
titanic = sns.load_dataset('titanic')

sns.set_style('whitegrid')

j1 = sns.jointplot(x='fare', y='age', data=titanic)

j2 = sns.jointplot(x='fare', y='age',kind='reg' ,data=titanic)

j3 = sns.jointplot(x='fare', y='age',kind='hex', data=titanic)

j4 = sns.jointplot(x='fare', y='age',kind='kde', data=titanic)

j1.fig.suptitle('titanic fare - scatter', size = 15)
j2.fig.suptitle('titanic fare - reg', size = 15)
j3.fig.suptitle('titanic fare - hex', size = 15)
j4.fig.suptitle('titanic fare - kde', size = 15)

plt.show()

# %%
titanic = sns.load_dataset('titanic')

sns.set_style('whitegrid')

g = sns.FacetGrid(data=titanic, col='who', row='survived')

g = g.map(plt.hist, 'age')

# %%
titanic_pair = titanic[['age','pclass','fare']]

g = sns.pairplot(titanic_pair)

# %%
# !pip install

# %%
df_car = pd.read_excel("D:/sample_data/car_in_seoul.xls",
                      header=1,
                      usecols="A,B,C,G,K,O,S")
df_car.head()
# Out:
#      기간  자치구       소계     소계.1    소계.2    소계.3  소계.4
# 0  2017  서울시  3116256  2641190  127564  339921  7581
# 1  2017  종로구    50828    41115    4055    5469   189
# 2  2017   중구    51540    40523    3508    7294   215
# 3  2017  용산구    77458    67335    2783    7221   119
# 4  2017  성동구   103116    87762    3698   11459   197

# %%
df_par = pd.read_excel("D:/sample_data/par_in_seoul.xls",
                      header=2,
                      usecols="A,B,C,I,O,W")
df_par.head()
# Out:
#      기간  자치구      개소  개소.3  개소.6   개소.10
# 0  2017  서울시  308025  8576  1977  297472
# 1  2017  종로구    7220   148   103    6969
# 2  2017   중구    4152   151    94    3907
# 3  2017  용산구    7291   362    75    6854
# 4  2017  성동구    6658   264    65    6329

# %%
df_car.rename(columns={df_car.columns[0]:"년도",
                      df_car.columns[1]:"자치구",
                      df_car.columns[2]:"합계",
                      df_car.columns[3]:"승용차",
                      df_car.columns[4]:"승합차",
                      df_car.columns[5]:"화물차",
                      df_car.columns[6]:"특수차"},
             inplace = True)
df_car.head()
# Out:
#      년도  자치구       합계      승용차     승합차     화물차   특수차
# 0  2017  서울시  3116256  2641190  127564  339921  7581
# 1  2017  종로구    50828    41115    4055    5469   189
# 2  2017   중구    51540    40523    3508    7294   215
# 3  2017  용산구    77458    67335    2783    7221   119
# 4  2017  성동구   103116    87762    3698   11459   197

# %%
df_par.rename(columns={
                      df_par.columns[0]:"년도",
                      df_par.columns[1]:"자치구",
                      df_par.columns[2]:"합계",
                      df_par.columns[3]:"노상",
                      df_par.columns[4]:"노외",
                      df_par.columns[5]:"건축물부설"},
             inplace = True)
df_par.head()
# Out:
#      년도  자치구      합계    노상    노외   건축물부설
# 0  2017  서울시  308025  8576  1977  297472
# 1  2017  종로구    7220   148   103    6969
# 2  2017   중구    4152   151    94    3907
# 3  2017  용산구    7291   362    75    6854
# 4  2017  성동구    6658   264    65    6329

# %%
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      27 non-null     int64
#  1   자치구     27 non-null     object
#  2   합계      27 non-null     object
#  3   승용차     27 non-null     object
#  4   승합차     27 non-null     object
#  5   화물차     27 non-null     object
#  6   특수차     27 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.6+ KB

# %%
df_par.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      26 non-null     int64
#  1   자치구     26 non-null     object
#  2   합계      26 non-null     int64
#  3   노상      26 non-null     int64
#  4   노외      26 non-null     int64
#  5   건축물부설   26 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.3+ KB

# %%
df_car
# Out:
#       년도   자치구       합계      승용차     승합차     화물차   특수차
# 0   2017   서울시  3116256  2641190  127564  339921  7581
# 1   2017   종로구    50828    41115    4055    5469   189
# 2   2017    중구    51540    40523    3508    7294   215
# 3   2017   용산구    77458    67335    2783    7221   119
# 4   2017   성동구   103116    87762    3698   11459   197
# 5   2017   광진구    98631    82951    4169   11248   263
# 6   2017  동대문구    97507    79837    4249   13244   177
# 7   2017   중랑구   113916    92596    5305   15619   396
# 8   2017   성북구   117209   100028    5745   11311   125
# 9   2017   강북구    77820    63987    4268    9416   149
# 10  2017   도봉구    97323    82048    4129   10937   209
# 11  2017   노원구   154708   134400    6291   13708   309
# 12  2017   은평구   129004   109372    5745   13636   251
# 13  2017  서대문구    86068    73356    3646    8764   302
# 14  2017   마포구   116531    99278    4662   12352   239
# 15  2017   양천구   150823   128605    5648   16034   536
# ...

# %%
df_car.drop([0], inplace=True)
df_car.drop([26], inplace=True)
df_par.drop([0], inplace=True)

# %%
df_car
# Out:
#       년도   자치구      합계     승용차   승합차    화물차   특수차
# 1   2017   종로구   50828   41115  4055   5469   189
# 2   2017    중구   51540   40523  3508   7294   215
# 3   2017   용산구   77458   67335  2783   7221   119
# 4   2017   성동구  103116   87762  3698  11459   197
# 5   2017   광진구   98631   82951  4169  11248   263
# 6   2017  동대문구   97507   79837  4249  13244   177
# 7   2017   중랑구  113916   92596  5305  15619   396
# 8   2017   성북구  117209  100028  5745  11311   125
# 9   2017   강북구   77820   63987  4268   9416   149
# 10  2017   도봉구   97323   82048  4129  10937   209
# 11  2017   노원구  154708  134400  6291  13708   309
# 12  2017   은평구  129004  109372  5745  13636   251
# 13  2017  서대문구   86068   73356  3646   8764   302
# 14  2017   마포구  116531   99278  4662  12352   239
# 15  2017   양천구  150823  128605  5648  16034   536
# 16  2017   강서구  202063  171936  8007  21740   380
# 17  2017   구로구  143960  119141  6805  17717   297
# 18  2017   금천구   86427   68119  4602  13565   141
# ...

# %%
df_car.info()
print("")
print("")

df_par.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      25 non-null     int64
#  1   자치구     25 non-null     object
#  2   합계      25 non-null     object
#  3   승용차     25 non-null     object
#  4   승합차     25 non-null     object
#  5   화물차     25 non-null     object
#  6   특수차     25 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.5+ KB
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      25 non-null     int64
#  1   자치구     25 non-null     object
#  2   합계      25 non-null     int64
#  3   노상      25 non-null     int64
#  4   노외      25 non-null     int64
#  5   건축물부설   25 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.3+ KB

# %%
df_car['합계'] = df_car['합계'].astype(int)
df_car['승용차'] = df_car['승용차'].astype(int)
df_car['승합차'] = df_car['승합차'].astype(int)
df_car['화물차'] = df_car['화물차'].astype(int)
df_car['특수차'] = df_car['특수차'].astype(int)
df_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      25 non-null     int64
#  1   자치구     25 non-null     object
#  2   합계      25 non-null     int32
#  3   승용차     25 non-null     int32
#  4   승합차     25 non-null     int32
#  5   화물차     25 non-null     int32
#  6   특수차     25 non-null     int32
# dtypes: int32(5), int64(1), object(1)
# memory usage: 1.0+ KB

# %%
df_car['승용차비율'] = (df_car['승용차']/df_car['합계'])*100
df_car['승합차비율'] = (df_car['승합차']/df_car['합계'])*100                
df_car['화물차비율'] = (df_car['화물차']/df_car['합계'])*100 
df_car.head(10)
# Out:
#       년도   자치구      합계     승용차   승합차    화물차  특수차      승용차비율     승합차비율  \
# 1   2017   종로구   50828   41115  4055   5469  189  80.890454  7.977886
# 2   2017    중구   51540   40523  3508   7294  215  78.624369  6.806364
# 3   2017   용산구   77458   67335  2783   7221  119  86.930982  3.592915
# 4   2017   성동구  103116   87762  3698  11459  197  85.109973  3.586252
# 5   2017   광진구   98631   82951  4169  11248  263  84.102361  4.226866
# 6   2017  동대문구   97507   79837  4249  13244  177  81.878224  4.357636
# 7   2017   중랑구  113916   92596  5305  15619  396  81.284455  4.656940
# 8   2017   성북구  117209  100028  5745  11311  125  85.341569  4.901501
# 9   2017   강북구   77820   63987  4268   9416  149  82.224364  5.484451
# 10  2017   도봉구   97323   82048  4129  10937  209  84.304841  4.242574
#
#         화물차비율
# 1   10.759817
# 2   14.152115
# 3    9.322472
# 4   11.112727
# 5   11.404122
# 6   13.582615
# 7   13.710980
# 8    9.650283
# 9   12.099717
# 10  11.237837

# %%
df_par['노상비율'] = (df_par['노상']/df_par['합계'])*100
df_par['노외비율'] = (df_par['노외']/df_par['합계'])*100                
df_par['건축물비율'] = (df_par['건축물부설']/df_par['합계'])*100 
df_par.head(10)
# Out:
#       년도   자치구     합계   노상   노외  건축물부설      노상비율      노외비율      건축물비율
# 1   2017   종로구   7220  148  103   6969  2.049861  1.426593  96.523546
# 2   2017    중구   4152  151   94   3907  3.636802  2.263969  94.099229
# 3   2017   용산구   7291  362   75   6854  4.965025  1.028665  94.006309
# 4   2017   성동구   6658  264   65   6329  3.965155  0.976269  95.058576
# 5   2017   광진구  16304  359   70  15875  2.201914  0.429342  97.368744
# 6   2017  동대문구   9485   30   57   9398  0.316289  0.600949  99.082762
# 7   2017   중랑구  12170  525   81  11564  4.313887  0.665571  95.020542
# 8   2017   성북구  13038  125  154  12759  0.958736  1.181163  97.860101
# 9   2017   강북구  10528   23   59  10446  0.218465  0.560410  99.221125
# 10  2017   도봉구   9593  460   61   9072  4.795163  0.635880  94.568957

# %%
df_car1 = df_car
df_car1.head()
# Out:
#      년도  자치구      합계    승용차   승합차    화물차  특수차      승용차비율     승합차비율      화물차비율
# 1  2017  종로구   50828  41115  4055   5469  189  80.890454  7.977886  10.759817
# 2  2017   중구   51540  40523  3508   7294  215  78.624369  6.806364  14.152115
# 3  2017  용산구   77458  67335  2783   7221  119  86.930982  3.592915   9.322472
# 4  2017  성동구  103116  87762  3698  11459  197  85.109973  3.586252  11.112727
# 5  2017  광진구   98631  82951  4169  11248  263  84.102361  4.226866  11.404122

# %%
del df_car1['승용차비율']

# %%
df_car1.head(3)
# Out:
#      년도  자치구     합계    승용차   승합차   화물차  특수차     승합차비율      화물차비율
# 1  2017  종로구  50828  41115  4055  5469  189  7.977886  10.759817
# 2  2017   중구  51540  40523  3508  7294  215  6.806364  14.152115
# 3  2017  용산구  77458  67335  2783  7221  119  3.592915   9.322472

# %%
df_car.head(3)
# Out:
#      년도  자치구     합계    승용차   승합차   화물차  특수차     승합차비율      화물차비율
# 1  2017  종로구  50828  41115  4055  5469  189  7.977886  10.759817
# 2  2017   중구  51540  40523  3508  7294  215  6.806364  14.152115
# 3  2017  용산구  77458  67335  2783  7221  119  3.592915   9.322472

# %%
df_car['승용차비율'] = (df_car['승용차']/df_car['합계'])*100

# %%
df_car1=df_car.copy()
df_par1=df_par.copy()

# %%
del df_car1['승용차']
del df_car1['승합차']
del df_car1['화물차']
del df_car1['특수차']

# %%
df_car1.head(3)
# Out:
#      년도  자치구     합계     승합차비율      화물차비율      승용차비율
# 1  2017  종로구  50828  7.977886  10.759817  80.890454
# 2  2017   중구  51540  6.806364  14.152115  78.624369
# 3  2017  용산구  77458  3.592915   9.322472  86.930982

# %%
df_car.head(3)
# Out:
#      년도  자치구     합계    승용차   승합차   화물차  특수차     승합차비율      화물차비율      승용차비율
# 1  2017  종로구  50828  41115  4055  5469  189  7.977886  10.759817  80.890454
# 2  2017   중구  51540  40523  3508  7294  215  6.806364  14.152115  78.624369
# 3  2017  용산구  77458  67335  2783  7221  119  3.592915   9.322472  86.930982

# %%
del df_par1['노상']
del df_par1['노외']
del df_par1['건축물부설']
df_par1.head(2)
# Out:
#      년도  자치구    합계      노상비율      노외비율      건축물비율
# 1  2017  종로구  7220  2.049861  1.426593  96.523546
# 2  2017   중구  4152  3.636802  2.263969  94.099229
